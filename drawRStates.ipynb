# %%
from IPython.display import IFrame
from transitions import *
from mukwembi_utils import *

# %% [markdown]
# # Drawing R-State Transition Graphs for some small graphs G.

# %% [markdown]
# ## K<sub>3</sub>

# %% [markdown]
# ## R = 1

# %%
G = nx.complete_graph(3)
R = 1
G = assign_random_labels(G, [0, 1])
TG = TransitionGraph(mukwembi_transition,  parameters = {"R":R} )
TG.expand_all_states(G, valid_states=[0, 1, 2])
TGX = TG.to_networkx()
build_interactive_view(G, TG, TGX, filename=f'K{3}R{R}.html', node_color_function=mukwembi_transition_coloring, graph_name=f"K{3}, R={R}")
IFrame(src='K3R1.html', width="100%", height=650)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="K3R1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## R = 2

# %%
G = nx.complete_graph(3)
R = 2
G = assign_random_labels(G, [0, 1])
TG = TransitionGraph(mukwembi_transition,  parameters = {"R":R} )
TG.expand_all_states(G, valid_states=[0, 1, 2])
TGX = TG.to_networkx()
build_interactive_view(G, TG, TGX, filename=f'K{3}R{R}.html', node_color_function=mukwembi_transition_coloring, graph_name=f"K{3}, R={R}")
IFrame(src='K3R1.html', width="100%", height=650)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="K3R1.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
